# %%
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the tweets dataset into a pandas DataFrame
reviews = pd.read_csv("add_merged_data.csv")

# %%
# Display the first few rows of the DataFrame
print(reviews.head())
# Out:
#    index                                             Review
# 0      1  Milo enak bget apa lagi yang harga 3.000 enak ...
# 1      2                                        Ngomong opo
# 2      3  I was totally broken when the love of my life ...
# 3      4  milo susu paling laris dan paling banyak manfa...
# 4      5                   Selalu minum milo,milo enak tau�

# %%
features = reviews.iloc[:, 1].values

# %%
processed_features = []

for sentence in range(0, len(features)):
    # Remove all the special characters
    processed_feature = re.sub(r'\W', ' ', str(features[sentence]))

    # remove all single characters
    processed_feature= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_feature)

    # Remove single characters from the start
    processed_feature = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_feature)

    # Substituting multiple spaces with single space
    processed_feature = re.sub(r'\s+', ' ', processed_feature, flags=re.I)

    # Removing prefixed 'b'
    processed_feature = re.sub(r'^b\s+', '', processed_feature)

    # Converting to Lowercase
    processed_feature = processed_feature.lower()

    processed_features.append(processed_feature)

# %%
print(processed_features)
# Out:
# ['milo enak bget apa lagi yang harga 3 000 enak bgt milo sih cocok bet buat anak anak karena selain rasanya yang enak milo juga mengandung milo yang baik bagi anak anak', 'ngomong opo', 'i was totally broken when the love of my life left me it was so hard for me almost gave up if not for friend who directed me to very good and powerful man called dr clement who helped me bring back the love of my life and now he treats me with so much love and care don know what problems you are passing through but with what he did for me know he can help you https wa me message hivaa3nk7mgdc1do not hesitate to get in touch with him if you need his helper lihat selengkapnya', 'milo susu paling laris dan paling banyak manfaatnya enaknya dapet hematnya dapet manfaatnya juga dapet', 'selalu minum milo milo enak tau ', 'pokoknya susu favoritt no debattt ', 'lebih enak susu indomie ', 'kok rasanya asin banget sih', 'admin ramah bintang 1 ', 'adminya ramah sekali yyyy', 'milo enak tauuuuuuuuuuuuuu', 'aku u
# ...

# %%
reviews['Review'] = processed_features

# %%
reviews.to_csv('cleaned_add_merged_data.csv', index=False)
