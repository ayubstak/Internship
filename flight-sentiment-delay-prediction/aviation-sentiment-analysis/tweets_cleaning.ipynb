# %%
import numpy as np
import pandas as pd
import re
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the tweets dataset into a pandas DataFrame
airline_tweets = pd.read_csv("tweets_super air jet.csv")

# %%
# Display the first few rows of the DataFrame
print(airline_tweets.head())
# Out:
#          userId         username                       date  \
# 0  3.088776e+08     bajangIdaman  2023-06-26 23:29:35+00:00
# 1  9.612571e+07  FazhriennyaNtan  2023-06-26 22:52:15+00:00
# 2  1.509780e+18        rex_aslan  2023-06-26 16:05:58+00:00
# 3  2.987771e+09         muflfins  2023-06-26 15:29:24+00:00
# 4  6.351765e+08      raratitihhh  2023-06-26 12:26:44+00:00
#
#                                              content       tweetId  \
# 0  @SuperAirJet min, ini IU717 mau berangkat jam ...  1.673470e+18
# 1                            @SuperAirJet min cek dm  1.673460e+18
# 2  @SuperAirJet Mohon info. Saat akan online cek ...  1.673360e+18
# 3  hallo @lionairgroup saya mau tanya. tadi saya ...  1.673350e+18
# 4  @indie_0 Ini pertama kali aku naik super air j...  1.673310e+18
#
#    replyCount  retweetCount  likeCount inReplyToUser    mentionedUsers  \
# 0           0             0          0           NaN   ['SuperAirJet']
# ...

# %%
features = airline_tweets.iloc[:, 3].values

# %%
processed_features = []

for sentence in range(0, len(features)):
    # Remove all the special characters
    processed_feature = re.sub(r'\W', ' ', str(features[sentence]))

    # remove all single characters
    processed_feature= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_feature)

    # Remove single characters from the start
    processed_feature = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_feature)

    # Substituting multiple spaces with single space
    processed_feature = re.sub(r'\s+', ' ', processed_feature, flags=re.I)

    # Removing prefixed 'b'
    processed_feature = re.sub(r'^b\s+', '', processed_feature)

    # Converting to Lowercase
    processed_feature = processed_feature.lower()

    processed_features.append(processed_feature)

# %%
print(processed_features)
# Out:
# [' superairjet min ini iu717 mau berangkat jam berapa boarding 5 30 jadwal 6 00 dan sekarang sudah 7 29 ada apa ini ', ' superairjet min cek dm', ' superairjet mohon info saat akan online cek in nomor dan waktu flight saya tiba² berubah dan ini tanpa pemberitahuan sebelumnya sebelumnya iu732 menjadi iu752 ', 'hallo lionairgroup saya mau tanya tadi saya dapet email dan wa terkait flight cancellation dari lion air ke super air jet apa itu berarti terminal keberangkatannya juga berubah ', ' indie_0 ini pertama kali aku naik super air jet kak klo liat di foto itu kapasitas koper kabin 7kg mending pake koper kecil kak tp klo untuk 20 inch aku kurang yakin bisa masuk kabin cuma aku pernah liat ada yg bawa koper mgkn seukuran itu dibawa masuk kabin tp beda pesawat kak ', ' superairjet min tolong cek dm ya makasih ', ' superairjet halo maaf saya melakukan kesalahan booking via agoda dengan kode booking 992378417 saya sudah bikin ticket di helpdesknya soalnya ga bisa cancel dari agoda ', 'sup
# ...

# %%
airline_tweets['content'] = processed_features

# %%
airline_tweets.to_csv('cleaned_tweets_super air jet.csv', index=False)
